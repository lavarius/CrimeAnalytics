# %% [markdown]
# <a href="https://colab.research.google.com/github/lavarius/CrimeAnalytics/blob/main/LA_Crime_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import requests
import pandas as pd

# %%
# # Define the API endpoint
# url = "https://data.lacity.org/resource/2nrs-mtv8.json"
# # Make a GET request to fetch the raw data
# response = requests.get(url)
# # Parse the JSON data
# data = response.json()
# # Convert the JSON data to a DataFrame
# crime = pd.DataFrame(data)

# crime = pd.read_csv('data/LA_Crime_Data_from_2020_to_Present_20240823.csv')
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
# !ls /content/drive/MyDrive/Colab\ Notebooks/data/LA_Crime_Data_from_2020_to_Present_20240823.csv
# Out:
# data  LA_Crime_Project.ipynb  SF_Crime_Project.ipynb

# %%
crime = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/LA_Crime_Data_from_2020_to_Present_20240823.csv')

# %%
crime.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130     7
# 1  200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800     1
# 2  200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700     3
# 3  200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037     9
# 4  220614831  08/18/2022 12:00:00 AM  08/17/2020 12:00:00 AM      1200     6
#
#    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0   Wilshire          784         1     510
# 1    Central          182         1     330
# 2  Southwest          356         1     480
# 3   Van Nuys          964         1     343
# 4  Hollywood          666         2     354
#
#                                 Crm Cd Desc  ... Status   Status Desc  \
# 0                          VEHICLE - STOLEN  ...     AA  Adult Arrest
# 1                     BURGLARY FROM VEHICLE  ...     IC   Invest Cont
# ...

# %%
crime.columns
# column name definitions on website https://data.lacity.org/Public-Safety/Crime-Data-from-2020-to-Present/2nrs-mtv8/about_data
# Out:
# Index(['DR_NO', 'Date Rptd', 'DATE OCC', 'TIME OCC', 'AREA', 'AREA NAME',
#        'Rpt Dist No', 'Part 1-2', 'Crm Cd', 'Crm Cd Desc', 'Mocodes',
#        'Vict Age', 'Vict Sex', 'Vict Descent', 'Premis Cd', 'Premis Desc',
#        'Weapon Used Cd', 'Weapon Desc', 'Status', 'Status Desc', 'Crm Cd 1',
#        'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'LOCATION', 'Cross Street', 'LAT',
#        'LON'],
#       dtype='object')
